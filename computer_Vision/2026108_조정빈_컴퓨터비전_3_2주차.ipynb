# %%
# !pip install opencv-python
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
# !wget -O gray_image.jpg "https://blog.aspose.cloud/ko/imaging/grayscale-image-in-java/images/grayscale.jpg" -q
# !wget -O hand_writing_image.jpg "https://thumbnews.nateimg.co.kr/view610///news.nateimg.co.kr/orgImg/ae/2023/10/13/ae_1697173144021_372706_4.png" -q

gray_image = cv2.imread("gray_image.jpg", cv2.IMREAD_GRAYSCALE)
hand_writing_image = cv2.imread('hand_writing_image.jpg', cv2.IMREAD_GRAYSCALE)

if gray_image is None:
   print("gray_image.jpg 로드 실패 이미지 경로를 확인하세요.")
else:
  print ("gray_image.jpg 로드 성공")

if hand_writing_image is None:
  print("'hand_urlting_Inage,Jpg'로드 실패 이미지 경로를 확인하세요.")
else:
  print ("hand_writing_image.Jpg 로드 성공")
# Out:
# gray_image.jpg 로드 성공
# hand_writing_image.Jpg 로드 성공

# %%
if gray_image is not None:
  threshold_value = 127
  max_value = 255

  ret, thres_binary = cv2.threshold(gray_image, threshold_value, max_value, cv2.THRESH_BINARY)
  print("[THRESH_BINARY]")
  cv2_imshow(thres_binary)

  ret, thres_binary_inv = cv2.threshold(gray_image, threshold_value, max_value, cv2.THRESH_BINARY_INV)
  print("[THRESH_BINARY_INV]")
  cv2_imshow(thres_binary_inv)

  ret, thres_trunc = cv2.threshold(gray_image, threshold_value, max_value, cv2.THRESH_TRUNC)
  print("[THRESH_TRUNC]")
  cv2_imshow(thres_trunc)

  ret, thres_tozero = cv2.threshold(gray_image, threshold_value, max_value, cv2.THRESH_TOZERO)
  print("[THRESH_TOZERO]")
  cv2_imshow(thres_tozero)

  ret, thres_tozero_inv = cv2.threshold(gray_image, threshold_value, max_value, cv2.THRESH_TOZERO_INV)
  print("[THRESH_TOZERO_INV]")
  cv2_imshow(thres_tozero_inv)
else:
  print("gray_image를 로드하지 못했습니다.")
# Out:
# [THRESH_BINARY]
# <PIL.Image.Image image mode=L size=550x413>
# [THRESH_BINARY_INV]
# <PIL.Image.Image image mode=L size=550x413>
# [THRESH_TRUNC]
# <PIL.Image.Image image mode=L size=550x413>
# [THRESH_TOZERO]
# <PIL.Image.Image image mode=L size=550x413>
# [THRESH_TOZERO_INV]
# <PIL.Image.Image image mode=L size=550x413>

# %%
if hand_writing_image is not None:
  block_size = 21
  C_val = 3

  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, C_val)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, C_val)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)

else:
  print("hand_writing_image를 로드하지 못했습니다.")
# Out:
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>

# %%
if gray_image is not None:
  ret_otsu, thres_otsu = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  print(f"[Otsu Threshold] 자동으로 찾은 임계값 : {ret_otsu}")
  cv2_imshow(thres_otsu)
else:
  print("gray_image가 None 입니다. 확인 후 다시 시도하세요")
# Out:
# [Otsu Threshold] 자동으로 찾은 임계값 : 105.0
# <PIL.Image.Image image mode=L size=550x413>

# %% [markdown]
# ##과제

# %%
#블록크기와 C값 변화를 통한 적응형 임계점 결과 비교
if hand_writing_image is not None:
  block_size = 21
  block_size1 = 31
  block_size2 = 51

  C_val1 = 0
  C_val2 = 5
  C_val3 = 10

  #C값 변화에 따른 임계점 결과 비교
  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, C_val1)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, C_val1)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)



  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, C_val2)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, C_val2)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)



  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size, C_val3)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, C_val3)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)

  #블록크기 변화에 따른 임계점 결과 비교
  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size1, C_val1)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size1, C_val1)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)

  thres_adaptive_mean = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, block_size2, C_val1)
  print("[Adaptive Mean Threshold]")
  cv2_imshow(thres_adaptive_mean)


  thres_adaptive_gaussian = cv2.adaptiveThreshold(hand_writing_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size2, C_val1)
  print("[Adaptive Gaussian Threshold]")
  cv2_imshow(thres_adaptive_gaussian)
else:
  print("hand_writing_image를 로드하지 못했습니다.")
# Out:
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Mean Threshold]
# <PIL.Image.Image image mode=L size=409x565>
# [Adaptive Gaussian Threshold]
# <PIL.Image.Image image mode=L size=409x565>

# %%
#오츄 알고리즘 + 가우시안 블러
gray_image = cv2.imread("gray_image.jpg", cv2.IMREAD_GRAYSCALE)

if gray_image is not None:
   blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

   ret_otsu, thres_otsu = cv2.threshold(blurred_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

   print(f"[Otsu Threshold] 자동으로 찾은 임계값: {ret_otsu}")

   cv2_imshow(thres_otsu)

else:
  print("gray_image가 None 입니다. 확인 후 다시 시도하세요")
# Out:
# [Otsu Threshold] 자동으로 찾은 임계값: 106.0
# <PIL.Image.Image image mode=L size=550x413>

# %%
#Color 이미지 이진화
color_image = cv2.imread('hand_writing_image.jpg')

if color_image is not None:
  gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)

  ret, thres_binary = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
  cv2_imshow(thres_binary)
else:
  print("color_image를 로드하지 못했습니다.")
# Out:
# <PIL.Image.Image image mode=L size=409x565>

# %%
#ROI만 이진화
image_copy = color_image.copy()

roi = image_copy[20:min(150, image_copy3.shape[0]), 70:min(200, image_copy3.shape[1])]

ret, thres_binary = cv2.threshold(roi, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(thres_binary)
# Out:
# <PIL.Image.Image image mode=RGB size=130x130>
